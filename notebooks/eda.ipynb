# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# ## Matome
#
# This notebook explores the salary dataset and displays the first few rows.

# %%
import pandas as pd

df = pd.read_csv('../data/salary_data.csv')
df.head()
